# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.dpi'] = 140

import psytrack as psy
import scipy.io

mouseList = ['zz054','zz062','zz063','zz066','zz067','zz068','zz069']
F = 5

# %%
def fitFull(mouse,nPrev,F):
    mat = scipy.io.loadmat('C:/Users/zzhu34/Documents/tempdata/octoData/psyTrackData/trialData/' + mouse +'_nPrev5.mat',mat_dtype=True)
    mat['y'] = mat['y'].flatten();mat['correct'] = mat['correct'].flatten();
    mat['dayLength'] = mat['dayLength'].flatten();mat['answer'] = mat['answer'].flatten();
    mat['inputs'] = {'stimulus': mat['stimulus'],'stimH': mat['stimH'], 'actionH': mat['actionH'],
                     'actionXposRewardH': mat['actionXposRewardH'],'actionXnegRewardH':mat['actionXnegRewardH']}
    del mat['stimulus'], mat['stimH'], mat['actionH'], mat['actionXposRewardH'],mat['actionXnegRewardH'],mat['dayIdx'],mat['removeFlag']
    
    
    # STIMULUS ACTION REWARD MODEL
    weights = {'bias': 1,  # a special key
               'stimulus': 1, 'stimH': 0,    # use only the first column of s1 from inputs  
               'actionH': 0, 'actionXposRewardH': nPrev, 'actionXnegRewardH': nPrev }    # use only the first column of s2 from inputs

    # It is often useful to have the total number of weights K in your model
    K = np.sum([weights[i] for i in weights.keys()]);

    hyper= {'sigInit': 2**4.,      # Set to a single, large value for all weights. Will not be optimized further.
            'sigma': [2**-4.]*K,   # Each weight will have it's own sigma optimized, but all are initialized the same
            'sigDay': 2**-2.}        # Indicates that session boundaries will be ignored in the optimization
    optList = ['sigma','sigDay']
    hyp, evd, wMode, hess_info = psy.hyperOpt(mat, hyper, weights, optList)
    xval_logli, xval_pL = psy.crossValidate(mat, hyper, weights, optList, F=F, seed=41)

    
    scipy.io.savemat('C:/Users/zzhu34/Documents/tempData/octoData/psyTrackData/psyTrackFit/' + mouse + 'psytrack_SBRpRn_nPrev' + str(nPrev) +'.mat',
                     {'xval_logli':xval_logli, 'xval_pL':xval_pL, 'hyp':hyp, 'evd':evd, 'wMode':wMode, 'hess_info':hess_info,
                     'hyper':hyper, 'optList':optList, 'weights':weights, 'K':K})

# %%
nPrev = 1;
for mouse in mouseList:
    fitFull(mouse,nPrev,F)
# Out:
# Running xval fold 5 of 5

# %%
nPrev = 2;
for mouse in mouseList:
    fitFull(mouse,nPrev,F)
# Out:
# Running xval fold 5 of 5

# %%
nPrev = 3;
for mouse in mouseList:
    fitFull(mouse,nPrev,F)
# Out:
# Running xval fold 5 of 5

# %%
nPrev = 4;
for mouse in mouseList:
    fitFull(mouse,nPrev,F)
# Out:
# Running xval fold 3 of 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9774e6db4a7c> in <module>
#       1 nPrev = 4;
#       2 for mouse in mouseList:
# ----> 3     fitFull(mouse,nPrev,F)
#
# <ipython-input-2-c58067ed88e4> in fitFull(mouse, nPrev, F)
#      21     optList = ['sigma','sigDay']
#      22     hyp, evd, wMode, hess_info = psy.hyperOpt(mat, hyper, weights, optList)
# ---> 23     xval_logli, xval_pL = psy.crossValidate(mat, hyper, weights, optList, F=F, seed=41)
#      24
#      25
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psytrack\helper\crossValidation.py in crossValidate(D, hyper_guess, weight_dict, optList, F, seed, verbose)
#      29             print("\rRunning xval fold " + str(f+1) + " of " + str(F), end="")
#      30         _, _, wMode, _ = hyperOpt(train_dats[f], hyper_guess, weight_dict,
# ---> 31                                   optList, hess_calc=None)
#      32         logli, gw = xval_loglike(test_dats[f], wMode,
#      33                                  train_dats[f]['missing_trials'], weight_dict)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psytrack\hyperOpt.py in hyperOpt(dat, hyper, weights, optList, method, showOpt, jump, hess_calc)
#     181             method='BFGS',
#     182             options=opts,
# --> 183             callback=callback,
#     184         )
#     185
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     593         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     594     elif meth == 'bfgs':
# --> 595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'newton-cg':
#     597         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     988             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
#     989                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# --> 990                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#     991         except _LineSearchError:
#     992             # Line search failed to find a better solution.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     808     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     809                              old_fval, old_old_fval,
# --> 810                              **kwargs)
#     811
#     812     if ret[0] is not None and extra_condition is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     173             alpha1 = stp
#     174             phi1 = phi(stp)
# --> 175             derphi1 = derphi(stp)
#     176         else:
#     177             break
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\linesearch.py in derphi(s)
#      88
#      89     def derphi(s):
# ---> 90         gval[0] = fprime(xk + s*pk, *newargs)
#      91         if gradient:
#      92             gc[0] += 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in approx_fprime(xk, f, epsilon, *args)
#     728
#     729     """
# --> 730     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     731
#     732
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     668         ei[k] = 1.0
#     669         d = epsilon * ei
# --> 670         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     671         ei[k] = 0.0
#     672     return grad
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psytrack\hyperOpt.py in hyperOpt_lossfun(optVals, keywords)
#     285     # Calculate likelihood and prior terms with new epsilon
#     286     pT, lT, _ = getPosteriorTerms(
# --> 287         E_flat, hyper=hyper, method=method, dat=dat, weights=weights)
#     288
#     289     # Calculate posterior term, then approximate evidence for new sigma
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psytrack\getMAP.py in getPosteriorTerms(E_flat, dat, hyper, weights, method)
#     322     logli = np.sum(y * gw - np.logaddexp(0, gw))
#     323     dlogli = DTinv_v(dlliList.flatten('F'), K)
# --> 324     ddlogli = {'H': myblk_diags(HlliList), 'K': K}
#     325
#     326     liTerms = {'logli': logli, 'dlogli': dlogli, 'ddlogli': ddlogli}
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psytrack\helper\helperFunctions.py in myblk_diags(A)
#      30     # After diagonals are constructed, use sparse function diags() to make
#      31     #   matrix, then blow up to full size
# ---> 32     return diags(d, offsets, shape=(N * K, N * K), format='csc')
#      33
#      34
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\sparse\construct.py in diags(diagonals, offsets, shape, format, dtype)
#     177             raise ValueError("Offset %d (index %d) out of bounds" % (offset, j))
#     178         try:
# --> 179             data_arr[j, k:k+length] = diagonal[...,:length]
#     180         except ValueError:
#     181             if len(diagonal) != length and len(diagonal) != 1:
#
# KeyboardInterrupt:
